# %%
import pandas as pd

# %%
df_pocos_exploratorios=pd.read_csv('pocos-exploratorios-jan26.csv', encoding='latin1')

df_pocos_exploratorios_2=df_pocos_exploratorios.copy()
print(df_pocos_exploratorios_2)
# Out:
# Running cells with 'Python 3.14.3' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/rafaella.almeida/AppData/Local/Python/pythoncore-3.14-64/python.exe -m pip install ipykernel -U --user --force-reinstall'
